# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,10,100)

# %%
plt.plot(x,x,label='Linear')
plt.show()

# %%
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
x=[150,140,120,110,100,90]
y=[6,8,10,11,23,21]

# %%
plt.scatter(x,y)
plt.show()

# %%
#pylab is a module in matplotlib that gets initialize alongside the matplotlib
import pylab as pl

# %%
ds=np.random.normal(5.0,4.0,100)
pl.hist(ds)
pl.xlabel("DS")
pl.show()
